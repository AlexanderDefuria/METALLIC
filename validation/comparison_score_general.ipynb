# %%
import matplotlib.pyplot as plt

# %%
Kappa_rg = [0.127, 0.102, 0.144, 0.148, 0.130, 0.109, 0.102, 0.019, 0.016]
Kappa_nn = [0.051, 0.048, 0.068, 0.053, 0.061, 0.158, 0.146, 0.270, 0.27]
Kappa_dl1 = [0.039, 0.032, 0.043, 0.034, 0.035, 0.039, 0.038, 0.027, 0.144]
Kappa_dl2 = [0.039, 0.031, 0.044, 0.044, 0.038, 0.037, 0.034, 0.006, 0.003]

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_rg, label='RG', marker='o')
plt.plot(metric, Kappa_nn, label='NN', marker='o')
plt.plot(metric, Kappa_dl1, label='DL1', marker='o')
plt.plot(metric, Kappa_dl2, label='DL2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different metrics')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_rg = [0.694, 0.648, 0.738, 0.689, 0.681, 0.571, 0.568, 0.088, 0.0964]
Kripp_nn = [0.325, 0.361, 0.430, 0.304, 0.397, 0.395, 0.313, 0.401, 0.397]
Kripp_dl1 = [0.323, 0.333, 0.337, 0.231, 0.275, 0.295, 0.283, 0.078, 0.217]
Kripp_dl2 = [0.358, 0.345, 0.365, 0.310, 0.312, 0.283, 0.283, 0.052, 0.044]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_rg, label='RG', marker='o')
plt.plot(metric, Kripp_nn, label='NN', marker='o')
plt.plot(metric, Kripp_dl1, label='DL1', marker='o')
plt.plot(metric, Kripp_dl2, label='DL2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different metrics')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec5_rg = [0.624, 0.56, 0.644, 0.635, 0.601, 0.572, 0.578, 0.340, 0.306]
Prec5_nn = [0.386, 0.381, 0.418, 0.377, 0.416, 0.454, 0.438, 0.510, 0.506]
Prec5_dl1 = [0.37, 0.37, 0.37, 0.311, 0.345, 0.365, 0.359, 0.256, 0.369]
Prec5_dl2 = [0.37, 0.361, 0.365, 0.328, 0.342, 0.358, 0.362, 0.241, 0.244]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec5_rg, label='RG', marker='o')
plt.plot(metric, Prec5_nn, label='NN', marker='o')
plt.plot(metric, Prec5_dl1, label='DL1', marker='o')
plt.plot(metric, Prec5_dl2, label='DL2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Precision@5')
plt.title('Comparison of Precision@5 across different metrics')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_rg = [0.022, 0.029, 0.011, 0.013, 0.009, 0.031, 0.035, 0.024, 0.033]
MSE_dl1 = [0.046, 0.062, 0.031, 0.032, 0.022, 0.11, 0.113, 0.037, 0.052]
MSE_dl2 = [0.041, 0.050, 0.029, 0.032, 0.023, 0.047, 0.053, 0.036, 0.047]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_rg, label='RG', marker='o')
plt.plot(metric, MSE_dl1, label='DL1', marker='o')
plt.plot(metric, MSE_dl2, label='DL2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different metrics')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
