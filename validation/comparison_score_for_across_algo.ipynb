# %%
import matplotlib.pyplot as plt

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %% [markdown]
# Decision Tree

# %%
Kappa_dt_rg = [0.136, 0.110, 0.146, 0.160, 0.119, 0.116, 0.133, 0.019, 0.020]
Kappa_dt_knn = [0.050, 0.044, 0.061, 0.055, 0.041, 0.015, 0.145, 0.261, 0.270]
Kappa_dt_nn1 = [0.039, 0.031, 0.038, 0.036, 0.029, 0.031, 0.044, 0.031, 0.132]
Kappa_dt_nn2 = [0.043, 0.040, 0.048, 0.028, 0.035, 0.041, 0.031, 0.001, 0.005]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_dt_rg, label='rg', marker='o')
plt.plot(metric, Kappa_dt_knn, label='knn', marker='o')
plt.plot(metric, Kappa_dt_nn1, label='nn1', marker='o')
plt.plot(metric, Kappa_dt_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers(Decision Tree)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_dt_rg = [0.735, 0.701, 0.762, 0.724, 0.688, 0.609, 0.593, 0.086, 0.119]
Kripp_dt_knn = [0.346, 0.394, 0.442, 0.301, 0.307, 0.416, 0.338, 0.393, 0.396]
Kripp_dt_nn1 = [0.337, 0.332, 0.340, 0.184, 0.177, 0.311, 0.287, 0.074, 0.229]
Kripp_dt_nn2 = [0.374, 0.367, 0.393, 0.248, 0.240, 0.332, 0.252, 0.024, 0.049]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_dt_rg, label='rg', marker='o')
plt.plot(metric, Kripp_dt_knn, label='knn', marker='o')
plt.plot(metric, Kripp_dt_nn1, label='nn1', marker='o')
plt.plot(metric, Kripp_dt_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers(Decision Tree)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_dt_rg = [0.646, 0.592, 0.657, 0.635, 0.621, 0.587, 0.599, 0.329, 0.311]
Prec_dt_knn = [0.386, 0.379, 0.397, 0.345, 0.347, 0.461, 0.449, 0.497, 0.492]
Prec_dt_nn1 = [0.391, 0.352, 0.379, 0.310, 0.298, 0.377, 0.366, 0.255, 0.392]
Prec_dt_nn2 = [0.378, 0.379, 0.365, 0.284, 0.310, 0.417, 0.355, 0.228, 0.243]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt_rg, label='rg', marker='o')
plt.plot(metric, Prec_dt_knn, label='knn', marker='o')
plt.plot(metric, Prec_dt_nn1, label='nn1', marker='o')
plt.plot(metric, Prec_dt_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers(Decision Tree)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_dt_rg = [0.017, 0.023, 0.011, 0.008, 0.006, 0.0029, 0.032, 0.022, 0.031]
MSE_dt_nn1 = [0.036, 0.049, 0.027, 0.018, 0.018, 0.117, 0.114, 0.034, 0.050]
MSE_dt_nn2 = [0.033, 0.043, 0.027, 0.022, 0.018, 0.045, 0.050, 0.034, 0.046]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_dt_rg, label='rg', marker='o')
plt.plot(metric, MSE_dt_nn1, label='nn1', marker='o')
plt.plot(metric, MSE_dt_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different classifiers(Decision Tree)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# KNN

# %%
Kappa_knn_rg = [0.157, 0.131, 0.131, 0.177, 0.157, 0.148, 0.145, 0.020, 0.015]
Kappa_knn_knn = [0.048, 0.037, 0.086, 0.047, 0.044, 0.163, 0.141, 0.269, 0.267]
Kappa_knn_nn1 = [0.055, 0.047, 0.052, 0.032, 0.046, 0.053, 0.044, 0.004, 0.143]
Kappa_knn_nn2 = [0.045, 0.039, 0.062, 0.049, 0.045, 0.052, 0.044, 0.002, 0.003]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_knn_rg, label='rg', marker='o')
plt.plot(metric, Kappa_knn_knn, label='knn', marker='o')
plt.plot(metric, Kappa_knn_nn1, label='nn1', marker='o')
plt.plot(metric, Kappa_knn_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers(KNN)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_knn_rg = [0.766, 0.717, 0.823, 0.760, 0.755, 0.627, 0.615, 0.081, 0.090]
Kripp_knn_knn = [0.376, 0.395, 0.530, 0.337, 0.398, 0.412, 0.332, 0.388, 0.388]
Kripp_knn_nn1 = [0.433, 0.440, 0.492, 0.278, 0.347, 0.408, 0.370, 0.081, 0.216]
Kripp_knn_nn2 = [0.450, 0.413, 0.484, 0.346, 0.405, 0.351, 0.343, 0.047, 0.046]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_knn_rg, label='rg', marker='o')
plt.plot(metric, Kripp_knn_knn, label='knn', marker='o')
plt.plot(metric, Kripp_knn_nn1, label='nn1', marker='o')
plt.plot(metric, Kripp_knn_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers(KNN)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_knn_rg = [0.693, 0.640, 0.721, 0.714, 0.685, 0.637, 0.623, 0.343, 0.303]
Prec_knn_knn = [0.422, 0.409, 0.489, 0.403, 0.426, 0.446, 0.439, 0.503, 0.507]
Prec_knn_nn1 = [0.437, 0.436, 0.445, 0.359, 0.372, 0.410, 0.404, 0.262, 0.366]
Prec_knn_nn2 = [0.412, 0.388, 0.423, 0.375, 0.378, 0.356, 0.375, 0.228, 0.249]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt_rg, label='rg', marker='o')
plt.plot(metric, Prec_dt_knn, label='knn', marker='o')
plt.plot(metric, Prec_dt_nn1, label='nn1', marker='o')
plt.plot(metric, Prec_dt_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers(KNN)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_knn_rg = [0.016, 0.019, 0.006, 0.007, 0.007, 0.025, 0.033, 0.026, 0.035]
MSE_knn_nn1 = [0.048, 0.066, 0.032, 0.025, 0.024, 0.107, 0.103, 0.039, 0.052]
MSE_knn_nn2 = [0.037, 0.048, 0.024, 0.022, 0.023, 0.046, 0.054, 0.035, 0.047]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_knn_rg, label='rg', marker='o')
plt.plot(metric, MSE_knn_nn1, label='nn1', marker='o')
plt.plot(metric, MSE_knn_nn2, label='nn2', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different classifiers(KNN)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
