# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %%
Kappa_dt = [0.039, 0.031, 0.038, 0.036, 0.029, 0.031, 0.044, 0.031, 0.132]
Kappa_gnb = [0.030, 0.013, 0.038, 0.034, 0.030, 0.032, 0.034, 0.032, 0.136]
Kappa_knn = [0.055, 0.047, 0.052, 0.032, 0.046, 0.053, 0.044, 0.004, 0.143]
Kappa_rf = [0.034, 0.033, 0.036, 0.036, 0.042, 0.033, 0.041, 0.026, 0.155]
Kappa_svm = [0.052, 0.037, 0.051, 0.041, 0.037, 0.042, 0.035, 0.055, 0.116]
Kappa_ada = [0.035, 0.029, 0.043, 0.026, 0.032, 0.043, 0.038, 0.012, 0.165]
Kappa_cat = [0.032, 0.031, 0.042, 0.032, 0.030, 0.031, 0.036, 0.019, 0.163]
Kappa_gb = [0.03, 0.031, 0.041, 0.036, 0.034, 0.048, 0.033, 0.038, 0.144]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_dt, label='dt', marker='o')
plt.plot(metric, Kappa_gnb, label='gnb', marker='o')
plt.plot(metric, Kappa_knn, label='knn', marker='o')
plt.plot(metric, Kappa_rf, label='rf', marker='o')
plt.plot(metric, Kappa_svm, label='svm', marker='o')
plt.plot(metric, Kappa_ada, label='ada', marker='o')
plt.plot(metric, Kappa_cat, label='cat', marker='o')
plt.plot(metric, Kappa_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_dt = [0.337, 0.332, 0.340, 0.184, 0.177, 0.311, 0.287, 0.074, 0.229]
Kripp_gnb = [0.234, 0.179, 0.211, 0.224, 0.256, 0.226, 0.237, 0.084, 0.216]
Kripp_knn = [0.433, 0.440, 0.492, 0.278, 0.347, 0.408, 0.370, 0.081, 0.216]
Kripp_rf = [0.315, 0.345, 0.309, 0.249, 0.313, 0.279, 0.303, 0.090, 0.228]
Kripp_svm = [0.318, 0.334, 0.408, 0.253, 0.327, 0.316, 0.228, 0.092, 0.193]
Kripp_ada = [0.334, 0.361, 0.338, 0.208, 0.247, 0.275, 0.267, 0.055, 0.231]
Kripp_cat = [0.315, 0.329, 0.295, 0.241, 0.313, 0.257, 0.279, 0.085, 0.229]
Kripp_gb = [0.299, 0.342, 0.307, 0.211, 0.217, 0.285, 0.293, 0.060, 0.190]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_dt, label='dt', marker='o')
plt.plot(metric, Kripp_gnb, label='gnb', marker='o')
plt.plot(metric, Kripp_knn, label='knn', marker='o')
plt.plot(metric, Kripp_rf, label='rf', marker='o')
plt.plot(metric, Kripp_svm, label='svm', marker='o')
plt.plot(metric, Kripp_ada, label='ada', marker='o')
plt.plot(metric, Kripp_cat, label='cat', marker='o')
plt.plot(metric, Kripp_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_dt = [0.391, 0.352, 0.379, 0.310, 0.298, 0.377, 0.366, 0.255, 0.392]
Prec_gnb = [0.315, 0.315, 0.330, 0.293, 0.337, 0.351, 0.334, 0.266, 0.365]
Prec_knn = [0.437, 0.436, 0.445, 0.359, 0.372, 0.410, 0.404, 0.262, 0.366]
Prec_rf = [0.378, 0.377, 0.330, 0.345, 0.378, 0.356, 0.378, 0.265, 0.381]
Prec_svm = [0.368, 0.328, 0.401, 0.345, 0.396, 0.374, 0.356, 0.266, 0.338]
Prec_ada = [0.373, 0.366, 0.368, 0.270, 0.316, 0.337, 0.335, 0.225, 0.379]
Prec_cat = [0.343, 0.369, 0.359, 0.308, 0.356, 0.335, 0.361, 0.257, 0.374]
Prec_gb = [0.355, 0.379, 0.319, 0.262, 0.308, 0.387, 0.334, 0.257, 0.361]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt, label='dt', marker='o')
plt.plot(metric, Prec_gnb, label='gnb', marker='o')
plt.plot(metric, Prec_knn, label='knn', marker='o')
plt.plot(metric, Prec_rf, label='rf', marker='o')
plt.plot(metric, Prec_svm, label='svm', marker='o')
plt.plot(metric, Prec_ada, label='ada', marker='o')
plt.plot(metric, Prec_cat, label='cat', marker='o')
plt.plot(metric, Prec_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_dt = [0.036, 0.049, 0.027, 0.018, 0.018, 0.117, 0.114, 0.034, 0.050]
MSE_gnb = [0.047, 0.061, 0.033, 0.038, 0.025, 0.106, 0.113, 0.036, 0.051]
MSE_knn = [0.048, 0.066, 0.032, 0.025, 0.024, 0.107, 0.103, 0.039, 0.052]
MSE_rf = [0.037, 0.056, 0.025, 0.025, 0.021, 0.109, 0.111, 0.036, 0.052]
MSE_svm = [0.077, 0.098, 0.039, 0.048, 0.031, 0.129, 0.125, 0.046, 0.057]
MSE_ada = [0.051, 0.062, 0.039, 0.036, 0.025, 0.109, 0.108, 0.036, 0.051]
MSE_cat = [0.035, 0.052, 0.024, 0.039, 0.021, 0.101, 0.112, 0.035, 0.050]
MSE_gb = [0.036, 0.053, 0.028, 0.030, 0.018, 0.102, 0.118, 0.035, 0.050]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_dt, label='dt', marker='o')
plt.plot(metric, MSE_gnb, label='gnb', marker='o')
plt.plot(metric, MSE_knn, label='knn', marker='o')
plt.plot(metric, MSE_rf, label='rf', marker='o')
plt.plot(metric, MSE_svm, label='svm', marker='o')
plt.plot(metric, MSE_ada, label='ada', marker='o')
plt.plot(metric, MSE_cat, label='cat', marker='o')
plt.plot(metric, MSE_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
