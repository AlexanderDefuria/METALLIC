# %%
import matplotlib.pyplot as plt

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %%
Kappa_dt = [0.136, 0.110, 0.146, 0.160, 0.119, 0.116, 0.133, 0.019, 0.020]
Kappa_gnb = [0.095, 0.063, 0.093, 0.136, 0.119, 0.091, 0.088, 0.023, 0.021]
Kappa_knn = [0.157, 0.131, 0.131, 0.177, 0.157, 0.148, 0.145, 0.020, 0.015]
Kappa_rf = [0.131, 0.126, 0.162, 0.155, 0.152, 0.122, 0.099, 0.026, 0.015]
Kappa_svm = [0.098, 0.076, 0.142, 0.143, 0.135, 0.077, 0.090, 0.015, 0.017]
Kappa_ada = [0.115, 0.084, 0.120, 0.135, 0.098, 0.100, 0.099, 0.013, 0.010]
Kappa_cat = [0.146, 0.120, 0.168, 0.165, 0.168, 0.123, 0.100, 0.021, 0.014]
Kappa_gb = [0.139, 0.103, 0.145, 0.140, 0.108, 0.104, 0.086, 0.016, 0.015]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_dt, label='dt', marker='o')
plt.plot(metric, Kappa_gnb, label='gnb', marker='o')
plt.plot(metric, Kappa_knn, label='knn', marker='o')
plt.plot(metric, Kappa_rf, label='rf', marker='o')
plt.plot(metric, Kappa_svm, label='svm', marker='o')
plt.plot(metric, Kappa_ada, label='ada', marker='o')
plt.plot(metric, Kappa_cat, label='cat', marker='o')
plt.plot(metric, Kappa_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_dt = [0.735, 0.701, 0.762, 0.724, 0.688, 0.609, 0.593, 0.086, 0.119]
Kripp_gnb = [0.588, 0.529, 0.595, 0.618, 0.617, 0.508, 0.510, 0.113, 0.126]
Kripp_knn = [0.766, 0.717, 0.823, 0.760, 0.755, 0.627, 0.615, 0.081, 0.090]
Kripp_rf = [0.747, 0.716, 0.776, 0.746, 0.773, 0.601, 0.614, 0.091, 0.101]
Kripp_svm = [0.624, 0.562, 0.750, 0.648, 0.672, 0.497, 0.506, 0.082, 0.062]
Kripp_ada = [0.630, 0.575, 0.685, 0.621, 0.598, 0.564, 0.541, 0.062, 0.072]
Kripp_cat = [0.738, 0.696, 0.764, 0.712, 0.720, 0.578, 0.592, 0.094, 0.098]
Kripp_gb = [0.727, 0.686, 0.757, 0.688, 0.630, 0.581, 0.579, 0.097, 0.104]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_dt, label='dt', marker='o')
plt.plot(metric, Kripp_gnb, label='gnb', marker='o')
plt.plot(metric, Kripp_knn, label='knn', marker='o')
plt.plot(metric, Kripp_rf, label='rf', marker='o')
plt.plot(metric, Kripp_svm, label='svm', marker='o')
plt.plot(metric, Kripp_ada, label='ada', marker='o')
plt.plot(metric, Kripp_cat, label='cat', marker='o')
plt.plot(metric, Kripp_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_dt = [0.646, 0.592, 0.657, 0.635, 0.621, 0.587, 0.599, 0.329, 0.311]
Prec_gnb = [0.543, 0.529, 0.573, 0.594, 0.552, 0.575, 0.554, 0.351, 0.311]
Prec_knn = [0.693, 0.640, 0.721, 0.714, 0.685, 0.637, 0.623, 0.343, 0.303]
Prec_rf = [0.667, 0.608, 0.666, 0.692, 0.680, 0.565, 0.583, 0.346, 0.314]
Prec_svm = [0.570, 0.483, 0.665, 0.630, 0.603, 0.548, 0.569, 0.348, 0.289]
Prec_ada = [0.565, 0.490, 0.575, 0.548, 0.497, 0.535, 0.541, 0.329, 0.288]
Prec_cat = [0.645, 0.570, 0.649, 0.670, 0.641, 0.564, 0.592, 0.342, 0.315]
Prec_gb = [0.658, 0.568, 0.646, 0.601, 0.530, 0.563, 0.566, 0.329, 0.320]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt, label='dt', marker='o')
plt.plot(metric, Prec_gnb, label='gnb', marker='o')
plt.plot(metric, Prec_knn, label='knn', marker='o')
plt.plot(metric, Prec_rf, label='rf', marker='o')
plt.plot(metric, Prec_svm, label='svm', marker='o')
plt.plot(metric, Prec_ada, label='ada', marker='o')
plt.plot(metric, Prec_cat, label='cat', marker='o')
plt.plot(metric, Prec_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_dt = [0.017, 0.023, 0.011, 0.008, 0.006, 0.0029, 0.032, 0.022, 0.031]
MSE_gnb = [0.033, 0.042, 0.018, 0.021, 0.012, 0.032, 0.037, 0.024, 0.031]
MSE_knn = [0.016, 0.019, 0.006, 0.007, 0.007, 0.025, 0.033, 0.026, 0.035]
MSE_rf = [0.018, 0.023, 0.009, 0.010, 0.007, 0.030, 0.035, 0.024, 0.032]
MSE_svm = [0.035, 0.045, 0.010, 0.018, 0.012, 0.038, 0.037, 0.029, 0.036]
MSE_ada = [0.020, 0.031, 0.014, 0.017, 0.011, 0.031, 0.035, 0.026, 0.034]
MSE_cat = [0.017, 0.023, 0.008, 0.0012, 0.007, 0.031, 0.035, 0.023, 0.032]
MSE_gb = [0.016, 0.025, 0.009, 0.0013, 0.008, 0.029, 0.035, 0.023, 0.032]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_dt, label='dt', marker='o')
plt.plot(metric, MSE_gnb, label='gnb', marker='o')
plt.plot(metric, MSE_knn, label='knn', marker='o')
plt.plot(metric, MSE_rf, label='rf', marker='o')
plt.plot(metric, MSE_svm, label='svm', marker='o')
plt.plot(metric, MSE_ada, label='ada', marker='o')
plt.plot(metric, MSE_cat, label='cat', marker='o')
plt.plot(metric, MSE_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
