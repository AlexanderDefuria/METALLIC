# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %%
Kappa_dt = [0.043, 0.040, 0.048, 0.028, 0.035, 0.041, 0.031, 0.001, 0.005]
Kappa_gnb = [0.035, 0.012, 0.040, 0.042, 0.037, 0.027, 0.031, 0.018, 0.002]
Kappa_knn = [0.045, 0.039, 0.062, 0.049, 0.045, 0.052, 0.044, 0.002, 0.003]
Kappa_rf = [0.035, 0.032, 0.045, 0.055, 0.040, 0.039, 0.042, 0.009, 0.009]
Kappa_svm = [0.045, 0.030, 0.041, 0.039, 0.037, 0.036, 0.028, 0.000, 0.010]
Kappa_ada = [0.032, 0.031, 0.042, 0.048, 0.037, 0.035, 0.027, 0.010, 0.001]
Kappa_cat = [0.035, 0.037, 0.037, 0.049, 0.042, 0.038, 0.035, 0.012, 0.003]
Kappa_gb = [0.046, 0.028, 0.043, 0.046, 0.031, 0.031, 0.041, 0.002, 0.003]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_dt, label='dt', marker='o')
plt.plot(metric, Kappa_gnb, label='gnb', marker='o')
plt.plot(metric, Kappa_knn, label='knn', marker='o')
plt.plot(metric, Kappa_rf, label='rf', marker='o')
plt.plot(metric, Kappa_svm, label='svm', marker='o')
plt.plot(metric, Kappa_ada, label='ada', marker='o')
plt.plot(metric, Kappa_cat, label='cat', marker='o')
plt.plot(metric, Kappa_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_dt = [0.374, 0.367, 0.393, 0.248, 0.240, 0.332, 0.252, 0.024, 0.049]
Kripp_gnb = [0.261, 0.222, 0.250, 0.271, 0.239, 0.188, 0.230, 0.074, 0.034]
Kripp_knn = [0.450, 0.413, 0.484, 0.346, 0.405, 0.351, 0.343, 0.047, 0.046]
Kripp_rf = [0.375, 0.387, 0.362, 0.342, 0.373, 0.280, 0.311, 0.058, 0.048]
Kripp_svm = [0.338, 0.352, 0.370, 0.318, 0.360, 0.276, 0.238, 0.021, 0.005]
Kripp_ada = [0.326, 0.266, 0.339, 0.280, 0.286, 0.272, 0.288, 0.060, 0.077]
Kripp_cat = [0.368, 0.388, 0.361, 0.358, 0.327, 0.290, 0.270, 0.067, 0.058]
Kripp_gb = [0.380, 0.372, 0.364, 0.317, 0.264, 0.278, 0.280, 0.064, 0.039]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_dt, label='dt', marker='o')
plt.plot(metric, Kripp_gnb, label='gnb', marker='o')
plt.plot(metric, Kripp_knn, label='knn', marker='o')
plt.plot(metric, Kripp_rf, label='rf', marker='o')
plt.plot(metric, Kripp_svm, label='svm', marker='o')
plt.plot(metric, Kripp_ada, label='ada', marker='o')
plt.plot(metric, Kripp_cat, label='cat', marker='o')
plt.plot(metric, Kripp_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_dt = [0.378, 0.379, 0.365, 0.284, 0.310, 0.417, 0.355, 0.228, 0.243]
Prec_gnb = [0.329, 0.311, 0.347, 0.294, 0.333, 0.311, 0.343, 0.277, 0.255]
Prec_knn = [0.412, 0.388, 0.423, 0.375, 0.378, 0.356, 0.375, 0.228, 0.249]
Prec_rf = [0.377, 0.388, 0.346, 0.375, 0.377, 0.354, 0.392, 0.243, 0.249]
Prec_svm = [0.361, 0.326, 0.374, 0.335, 0.374, 0.366, 0.357, 0.248, 0.237]
Prec_ada = [0.381, 0.329, 0.356, 0.288, 0.333, 0.348, 0.373, 0.257, 0.245]
Prec_cat = [0.377, 0.406, 0.363, 0.343, 0.321, 0.370, 0.360, 0.241, 0.273]
Prec_gb = [0.396, 0.361, 0.354, 0.334, 0.316, 0.348, 0.343, 0.259, 0.241]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt, label='dt', marker='o')
plt.plot(metric, Prec_gnb, label='gnb', marker='o')
plt.plot(metric, Prec_knn, label='knn', marker='o')
plt.plot(metric, Prec_rf, label='rf', marker='o')
plt.plot(metric, Prec_svm, label='svm', marker='o')
plt.plot(metric, Prec_ada, label='ada', marker='o')
plt.plot(metric, Prec_cat, label='cat', marker='o')
plt.plot(metric, Prec_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MSE_dt = [0.033, 0.043, 0.027, 0.022, 0.018, 0.045, 0.050, 0.034, 0.046]
MSE_gnb = [0.048, 0.054, 0.037, 0.039, 0.025, 0.046, 0.057, 0.036, 0.046]
MSE_knn = [0.037, 0.048, 0.024, 0.022, 0.023, 0.046, 0.054, 0.035, 0.047]
MSE_rf = [0.040, 0.045, 0.027, 0.028, 0.024, 0.042, 0.049, 0.036, 0.047]
MSE_svm = [0.059, 0.078, 0.033, 0.041, 0.026, 0.065, 0.059, 0.045, 0.051]
MSE_ada = [0.038, 0.047, 0.028, 0.037, 0.025, 0.044, 0.051, 0.034, 0.046]
MSE_cat = [0.035, 0.046, 0.024, 0.036, 0.024, 0.045, 0.054, 0.035, 0.046]
MSE_gb = [0.036, 0.042, 0.029, 0.033, 0.021, 0.043, 0.049, 0.035, 0.044]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, MSE_dt, label='dt', marker='o')
plt.plot(metric, MSE_gnb, label='gnb', marker='o')
plt.plot(metric, MSE_knn, label='knn', marker='o')
plt.plot(metric, MSE_rf, label='rf', marker='o')
plt.plot(metric, MSE_svm, label='svm', marker='o')
plt.plot(metric, MSE_ada, label='ada', marker='o')
plt.plot(metric, MSE_cat, label='cat', marker='o')
plt.plot(metric, MSE_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('MSE')
plt.title('Comparison of MSE across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
