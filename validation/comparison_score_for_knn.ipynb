# %%
import matplotlib.pyplot as plt

# %%
metric=["F1","G-mean","Acc","Precision","Recall","ROCAUC","PRAUC","BalACC","CWA"]

# %%
Kappa_dt = [0.050, 0.044, 0.061, 0.055, 0.041, 0.015, 0.145, 0.261, 0.270]
Kappa_gnb = [0.052, 0.038, 0.064, 0.059, 0.071, 0.159, 0.140, 0.273, 0.270]
Kappa_knn = [0.048, 0.037, 0.086, 0.047, 0.044, 0.163, 0.141, 0.269, 0.267]
Kappa_rf = [0.050, 0.049, 0.066, 0.055, 0.063, 0.169, 0.153, 0.282, 0.281]
Kappa_svm = [0.063, 0.076, 0.071, 0.058, 0.078, 0.163, 0.150, 0.267, 0.262]
Kappa_ada = [0.048, 0.067, 0.052, 0.052, 0.051, 0.144, 0.138, 0.266, 0.265]
Kappa_cat = [0.048, 0.042, 0.075, 0.058, 0.080, 0.165, 0.157, 0.278, 0.275]
Kappa_gb = [0.049, 0.038, 0.071, 0.046, 0.066, 0.154, 0.151, 0.265, 0.270]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kappa_dt, label='dt', marker='o')
plt.plot(metric, Kappa_gnb, label='gnb', marker='o')
plt.plot(metric, Kappa_knn, label='knn', marker='o')
plt.plot(metric, Kappa_rf, label='rf', marker='o')
plt.plot(metric, Kappa_svm, label='svm', marker='o')
plt.plot(metric, Kappa_ada, label='svm', marker='o')
plt.plot(metric, Kappa_cat, label='cat', marker='o')
plt.plot(metric, Kappa_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Kappa')
plt.title('Comparison of Kappa across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Kripp_dt = [0.346, 0.394, 0.442, 0.301, 0.307, 0.416, 0.338, 0.393, 0.396]
Kripp_gnb = [0.268, 0.298, 0.322, 0.277, 0.378, 0.323, 0.242, 0.393, 0.385]
Kripp_knn = [0.376, 0.395, 0.530, 0.337, 0.398, 0.412, 0.332, 0.388, 0.388]
Kripp_rf = [0.341, 0.374, 0.439, 0.352, 0.418, 0.415, 0.343, 0.412, 0.403]
Kripp_svm = [0.328, 0.356, 0.478, 0.286, 0.435, 0.379, 0.263, 0.414, 0.400]
Kripp_ada = [0.262, 0.326, 0.353, 0.256, 0.368, 0.382, 0.292, 0.394, 0.406]
Kripp_cat = [0.430, 0.369, 0.446, 0.325, 0.472, 0.417, 0.346, 0.394, 0.392]
Kripp_gb = [0.348, 0.375, 0.433, 0.299, 0.403, 0.414, 0.353, 0.419, 0.413]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Kripp_dt, label='dt', marker='o')
plt.plot(metric, Kripp_gnb, label='gnb', marker='o')
plt.plot(metric, Kripp_knn, label='knn', marker='o')
plt.plot(metric, Kripp_rf, label='rf', marker='o')
plt.plot(metric, Kripp_svm, label='svm', marker='o')
plt.plot(metric, Kripp_ada, label='svm', marker='o')
plt.plot(metric, Kripp_cat, label='cat', marker='o')
plt.plot(metric, Kripp_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('Krippendorf')
plt.title('Comparison of Krippendorf across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Prec_dt = [0.386, 0.379, 0.397, 0.345, 0.347, 0.461, 0.449, 0.497, 0.492]
Prec_gnb = [0.360, 0.361, 0.394, 0.378, 0.413, 0.434, 0.414, 0.525, 0.503]
Prec_knn = [0.422, 0.409, 0.489, 0.403, 0.426, 0.446, 0.439, 0.503, 0.507]
Prec_rf = [0.401, 0.404, 0.419, 0.408, 0.423, 0.489, 0.477, 0.520, 0.505]
Prec_svm = [0.418, 0.405, 0.499, 0.399, 0.466, 0.466, 0.439, 0.510, 0.512]
Prec_ada = [0.356, 0.350, 0.354, 0.342, 0.391, 0.430, 0.403, 0.511, 0.511]
Prec_cat = [0.374, 0.372, 0.394, 0.390, 0.461, 0.479, 0.458, 0.516, 0.507]
Prec_gb = [0.370, 0.374, 0.395, 0.354, 0.403, 0.431, 0.432, 0.501, 0.515]

# %%
plt.figure(figsize=(10, 6))
plt.plot(metric, Prec_dt, label='dt', marker='o')
plt.plot(metric, Prec_gnb, label='gnb', marker='o')
plt.plot(metric, Prec_knn, label='knn', marker='o')
plt.plot(metric, Prec_rf, label='rf', marker='o')
plt.plot(metric, Prec_svm, label='svm', marker='o')
plt.plot(metric, Prec_ada, label='svm', marker='o')
plt.plot(metric, Prec_cat, label='cat', marker='o')
plt.plot(metric, Prec_gb, label='gb', marker='o')
plt.xlabel('Metrics')
plt.ylabel('precision@5')
plt.title('Comparison of precision@5 across different classifiers')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
